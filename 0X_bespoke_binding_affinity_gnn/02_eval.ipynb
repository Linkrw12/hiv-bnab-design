# %% [markdown]
# # Eval model

# %%
# Not included in training; used to evaluate performance on unseen data
external_val_data_path = "data"

# %%
# Training and validation dataset paths to train and stop models
val_data_path = "data/"

SEED = 255
